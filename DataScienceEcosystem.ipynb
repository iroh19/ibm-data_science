# %% [markdown]
# ## Data Science Tools and Ecosystem

# %% [markdown]
# ## Author
# Batuhan

# %% [markdown]
# ##
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
#  ## **Objectives:**
#
# - List popular languages for Data Science
# - Create tables and lists using Markdown in Jupyter Notebook
# - Identify commonly used Data Science tools and environments
# - Write and interpret arithmetic expressions in Python
# - Understand basic version control operations using Git

# %% [markdown]
# ##
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# ##
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. Numpy
# 2. Pandas
# 3. Matplotlib

# %% [markdown]
# ##
# | Data Science Tools        |
# |---------------------------|
# | Jupyter Notebook          |
# | RStudio                   |
# | Spyder                    |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
## This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours and minutes
minutes = 200
hour = 60

how_much_hour = int(minutes / hour)
how_much_minute = int(minutes % hour)
print(f"{how_much_hour} hours {how_much_minute} minute")
# Out:
# 3 hours 20 minute
